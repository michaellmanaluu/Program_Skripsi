# %%
# !pip install google-play-scraper
# Out:
# Requirement already satisfied: google-play-scraper in /usr/local/lib/python3.12/dist-packages (1.2.7)

# %%
from google_play_scraper import app
import pandas as pd
import numpy as np

# %%
#Scrape desired number of reviews
#Run kode ini jika ingin scrape data dengan jumlah tertentu. Ganti (misal, ingin scrape sejumlah 1000, maka ganti kode , count = 1000 )

from google_play_scraper import Sort, reviews

result, continuation_token = reviews(
    'blibli.mobile.commerce',
    lang='id', # defaults to 'en'
    country='id', # defaults to 'us'
    sort=Sort.NEWEST, # defaults to Sort.MOST_RELEVANT you can use Sort.NEWEST to get newst reviews
    count=500, # defaults to 100
    filter_score_with=None # defaults to None(means all score) Use 1 or 2 or 3 or 4 or 5 to select certain score
)

# %%
df_busu = pd.DataFrame(np.array(result),columns=['review'])

df_busu = df_busu.join(pd.DataFrame(df_busu.pop('review').tolist()))

df_busu.head()
# Out:
#                                reviewId           userName  \
# 0  4d098252-b0cd-4534-9608-696a7e55be8a   Yenti Ummi Hilya
# 1  d9a17b13-6fc6-473e-b6ed-2fcc6b0c8086  Hendrik Kurniawan
# 2  7c55d319-a5f0-4806-ba30-6931f74e3f9e        Andre Dylan
# 3  13829b2d-b70d-41cd-8475-0de3d136f4ce   Abuhusen Mafaqih
# 4  43877790-cd65-44d0-907f-e23a83ba2a18        Wahyu Rizky
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a/ACg8oc...
# 1  https://play-lh.googleusercontent.com/a-/ALV-U...
# 2  https://play-lh.googleusercontent.com/a/ACg8oc...
# 3  https://play-lh.googleusercontent.com/a/ACg8oc...
# 4  https://play-lh.googleusercontent.com/a/ACg8oc...
#
#                                              content  score  thumbsUpCount  \
# 0                  sering sering kasi cash back ya 🥰      5              0
# 1                                                 ok      5              0
# 2  bikin argo murah nyari keuntungan sendiri biki...      1              0
# 3  aplikasi ga bermutu ga membatu menemukan baran...      1              0
# 4                             bagus sekali saya suka      5              0
#
#   reviewCreatedVersion                  at  \
# 0               12.6.0 2025-09-01 22:47:57
# 1               12.6.0 2025-09-01 13:20:47
# 2                 None 2025-09-01 03:09:06
# 3               12.6.0 2025-08-31 23:14:37
# 4               12.6.0 2025-08-31 23:06:51
#
#                                         replyContent           repliedAt  \
# 0  Hi kak! Makasih banget ya udah menjadikan blib... 2025-09-01 23:17:59
# 1  Halo kak Hendrik mantap! Makasih banyak buat r... 2025-09-02 09:29:34
# 2  Halo kak Andre Dylan mohon maaf terkait kendal... 2025-09-01 03:59:37
# 3  Halo kak Abuhusen mohon maaf atas pengalaman b... 2025-08-31 23:39:26
# 4  Halo kak Wahyu mantap! Makasih banyak buat rev... 2025-08-31 23:41:13
#
#   appVersion
# 0     12.6.0
# 1     12.6.0
# 2       None
# 3     12.6.0
# 4     12.6.0

# %%
len(df_busu.index) #count the number of data we got
# Out:
# 500

# %%
df_busu[['userName', 'score','at', 'content']].head()  #preview userName, rating, date-time, and reviews only
# Out:
#             userName  score                  at  \
# 0   Yenti Ummi Hilya      5 2025-09-01 22:47:57
# 1  Hendrik Kurniawan      5 2025-09-01 13:20:47
# 2        Andre Dylan      1 2025-09-01 03:09:06
# 3   Abuhusen Mafaqih      1 2025-08-31 23:14:37
# 4        Wahyu Rizky      5 2025-08-31 23:06:51
#
#                                              content
# 0                  sering sering kasi cash back ya 🥰
# 1                                                 ok
# 2  bikin argo murah nyari keuntungan sendiri biki...
# 3  aplikasi ga bermutu ga membatu menemukan baran...
# 4                             bagus sekali saya suka

# %%
#Run This Code to Sort the Data By Date

new_df = df_busu[['userName', 'score','at', 'content']]
sorted_df = new_df.sort_values(by='at', ascending=False) #Sort by Newst, change to True if you want to sort by Oldest.
sorted_df.head()
# Out:
#             userName  score                  at  \
# 0   Yenti Ummi Hilya      5 2025-09-01 22:47:57
# 1  Hendrik Kurniawan      5 2025-09-01 13:20:47
# 2        Andre Dylan      1 2025-09-01 03:09:06
# 3   Abuhusen Mafaqih      1 2025-08-31 23:14:37
# 4        Wahyu Rizky      5 2025-08-31 23:06:51
#
#                                              content
# 0                  sering sering kasi cash back ya 🥰
# 1                                                 ok
# 2  bikin argo murah nyari keuntungan sendiri biki...
# 3  aplikasi ga bermutu ga membatu menemukan baran...
# 4                             bagus sekali saya suka

# %%
my_df = sorted_df[['userName', 'score','at', 'content']] #get userName, rating, date-time, and reviews only

# %%
my_df.head()
# Out:
#             userName  score                  at  \
# 0   Yenti Ummi Hilya      5 2025-09-01 22:47:57
# 1  Hendrik Kurniawan      5 2025-09-01 13:20:47
# 2        Andre Dylan      1 2025-09-01 03:09:06
# 3   Abuhusen Mafaqih      1 2025-08-31 23:14:37
# 4        Wahyu Rizky      5 2025-08-31 23:06:51
#
#                                              content
# 0                  sering sering kasi cash back ya 🥰
# 1                                                 ok
# 2  bikin argo murah nyari keuntungan sendiri biki...
# 3  aplikasi ga bermutu ga membatu menemukan baran...
# 4                             bagus sekali saya suka

# %%
my_df.to_csv("scrapped_data.csv", index = False)  #Save the file as CSV , to download: click the folder icon on the left. the csv file should be there.
